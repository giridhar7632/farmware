# %% [markdown]
# <a href="https://colab.research.google.com/github/giridhar7632/farmware/blob/model/Farmware.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## soil moisture content detection using remote sensing
